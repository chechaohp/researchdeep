# %%
# !python p05_percept.py

# %%
# !python p06_spam.py
# Out:
# [0.13708772717074266, array([ 35., 554., 227., ...,   7.,   1.,   1.]), array([1.793e+03, 1.251e+03, 1.459e+03, ..., 1.000e+00, 7.000e+00,
#        7.000e+00])]
# Naive Bayes had an accuracy of 0.9802867383512545 on the testing set
# The top 5 indicative words for Naive Bayes are:  ['claim', 'prize', 'won', 'tone', 'guaranteed']
# The optimal SVM radius was 0.1
# The SVM model had an accuracy of 0.967741935483871 on the testing set

# %%
import matplotlib.pyplot as plt
import util

plt.figure()
Xa, Ya = util.load_csv('../data/ds1_a.csv', add_intercept=True)
plt.plot(Xa[:, 1][Ya == 1], Xa[:, 2][Ya == 1], 'ro')
plt.plot(Xa[:, 1][Ya == -1], Xa[:, 2][Ya == -1], 'bo')
plt.show()

plt.figure()
Xb, Yb = util.load_csv('../data/ds1_b.csv', add_intercept=True)
plt.plot(Xb[:, 1][Yb == 1], Xb[:, 2][Yb == 1], 'rx')
plt.plot(Xb[:, 1][Yb == -1], Xb[:, 2][Yb == -1], 'bx')
plt.show()

# 因为dataB线性可分，所以theta会无限增大来使逻辑回归的损失函数更小，所以要增加正则项
